# %% [markdown]
# <a href="https://colab.research.google.com/github/m-lil-coder/hello-world/blob/main/day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1)
print(1.8)
print("tanu")
# Out:
# 1
# 1.8
# tanu
